# %%
#cd C:\Users\donfa\OneDrive\Desktop\WORKING\DATA WORKING\Formation DATA\2. Regression\2.1. Regression lineaire Simple

# %% [markdown]
# # DATA PREPROCESSING

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer

#cd C:\Users\donfa\Desktop\WORKING\DATA WORKING\Formation DATA\1. DataProcessing
dataset=pd.read_csv('Salary_Data.csv')
dataset.head()
X_initial=dataset.iloc[:, :-1].values
# il faut commenter qu'on importe les donnes initiales

Y=dataset.iloc[:, -1].values
#imputer=SimpleImputer(missing_values=np.nan, strategy='mean')
#imputer.fit(X[:, 1:3])
#X[:,1:3]=imputer.transform(X[:,1:3])

#from sklearn.preprocessing import LabelEncoder,OneHotEncoder
#from sklearn.compose import ColumnTransformer

#labelencoder_X=LabelEncoder()

#X[:, 0]=labelencoder_X.fit_transform(X[:, 0])
## Encodage One-Hot
#onehotencoder = OneHotEncoder()
#columnTransformer = ColumnTransformer([("one_hot_encoder", OneHotEncoder(), [0])], remainder='passthrough')
#X = columnTransformer.fit_transform(X)

#labelencoder_Y=LabelEncoder()
#Y=labelencoder_Y.fit_transform(Y[:])

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X_initial, Y, test_size=1/3.0, random_state=0)

#from sklearn.preprocessing import StandardScaler

#sc_X = StandardScaler()

#X_train = sc_X.fit_transform(X_train)

#X_test = sc_X.fit_transform(X_test)

# %% [markdown]
# ## debut de la regression

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=regressor.predict(X_test)

# %%
plt.figure()
#ici il faut plutot utiliser plott
plt.plot(X_test, Y_test, color='red')
plt.plot(X_test, Y_pred, color='blue')
